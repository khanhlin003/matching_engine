# %%
# Imports
import pandas as pd
import datetime

# %%
# Read Excel files

#  To change
folder_path = "DataSets/example-set/"

df_clients = pd.read_csv(folder_path + 'input_clients.csv')
df_instruments = pd.read_csv(folder_path + 'input_instruments.csv')
df_orders = pd.read_csv(folder_path + 'input_orders.csv')

# for i in df_orders.index:
#     # df_orders["Time"][i] = datetime.datetime.strptime(df_orders["Time"][i] , "%H:%M:%S").time()
#     df_orders.loc[i, "Time"] = datetime.datetime.strptime(df_orders["Time"][i] , "%H:%M:%S").time()

print("Clients")
print(df_clients.to_string())

print("Instruments")
print(df_instruments.to_string())

print("Orders")
print(df_orders.to_string())
# Out:
# Clients
#   ClientID   Currencies PositionCheck  Rating
# 0        A      USD,SGD             Y       1
# 1        B  USD,SGD,JPY             N       2
# 2        C          SGD             Y       3
# 3        D          USD             Y       4
# 4        E          SGD             N       5
# Instruments
#   InstrumentID Currency  LotSize
# 0          SIA      SGD      100
# Orders
#         Time OrderID Instrument  Quantity Client   Price  Side
# 0    9:00:01      A1        SIA      1500      A  Market   Buy
# 1    9:02:00      B1        SIA      4500      B    32.1  Sell
# 2    9:05:00      C1        SIA       100      C      32   Buy
# 3    9:10:00      D1        SIA       300      D  Market  Sell
# 4    9:29:01      B2        SIA         5      B    32.1  Sell
# 5    9:29:02      E1        SIA      1000      E      32  Sell
# 6    9:29:03      A2        SIA       800      A    31.9   Buy
# 7    9:30:01      C2        SIA       100      C  Market  Sell
# 8    9:40:00      B3        SIA       500      B    32.2  Sell
# 9   10:50:00      C3        SIA      4200      C    32.2   Buy
# 10  11:10:00      B4        SIA       100      B  Market  Sell
# 11  12:30:00      E2        SIA       600      E    31.9   Buy
# 12  13:50:00      B5        SIA      1000      B      31  Sell
# 13  16:00:01      C4        SIA       600      C      32  Sell
# 14  16:01:00      B6        SIA       100      B    32.1  Sell
# 15  16:05:00      A3        SIA       300      A    31.9   Buy
# 16  16:09:59      E3        SIA      2000      E    31.8   Buy

# %%
class Client:
    def __init__(self, client_id, currencies, position_check, rating):
        self.client_id = client_id
        self.currencies =currencies
        self.position_check = position_check
        self.rating = rating

    def __str__(self):
        return "{Client}: " + self.__dict__.__str__()
    

    def __repr__(self):
        return self.__str__()

clients = []

for i in df_clients.index:
    clients.append(Client(
        df_clients["ClientID"][i],
        df_clients["Currencies"][i],
        df_clients["PositionCheck"][i],
        df_clients["Rating"][i]
    ))

print(clients)
# Out:
# [{Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, {Client}: {'client_id': 'D', 'currencies': 'USD', 'position_check': 'Y', 'rating': 4}, {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}]

# %%
class Instrument:
    def __init__(self, instrumentID, currency, lotsize):
        self.instrumentID = instrumentID
        self.currency = currency
        self.lotsize = lotsize

    def __str__(self):
        return "{Instrument}: " + self.__dict__.__str__()
    

    def __repr__(self) -> str:
        return self.__str__()

instruments = []

for i in df_instruments.index:
    instruments.append(Instrument(
        df_instruments["InstrumentID"][i],
        df_instruments["Currency"][i],
        df_instruments["LotSize"][i]
    ))

print(instruments)
# Out:
# [{Instrument}: {'instrumentID': 'SIA', 'currency': 'SGD', 'lotsize': 100}]

# %%
class Order:
    def __init__(self, time, order_id, client, instrument, side, price, quantity):
        self.time = time
        self.order_id = order_id
        self.client = client
        self.instrument = instrument
        self.side = side
        self.price = price if price == "Market" else float(price)
        self.quantity = float(quantity)

    def __str__(self):
        return "{Order}: " + self.__dict__.__str__()
    

    def __repr__(self):
        return self.__str__()

orders = []

for i in df_orders.index:
    # df_orders["Time"][i] = datetime.datetime.strptime(df_orders["Time"][i] , "%H:%M:%S").time()
    client = [c for c in clients if c.client_id == df_orders["Client"][i]][0]
    # instrument = [i for i in instruments if i.instrumentID == df_orders["Instrument"][i]][0]

    orders.append(
        Order(
            datetime.datetime.strptime(df_orders["Time"][i], "%H:%M:%S").time(),
            df_orders["OrderID"][i],
            # df_orders["Client"][i],
            client,
            df_orders["Instrument"][i],
            # instrument,
            df_orders["Side"][i],
            df_orders["Price"][i],
            df_orders["Quantity"][i],
        )
    )
    # df_orders.loc[i, "Time"] = datetime.datetime.strptime(df_orders["Time"][i] , "%H:%M:%S").time()

print(orders)
# Out:
# [{Order}: {'time': datetime.time(9, 0, 1), 'order_id': 'A1', 'client': {Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, 'instrument': 'SIA', 'side': 'Buy', 'price': 'Market', 'quantity': 1500.0}, {Order}: {'time': datetime.time(9, 2), 'order_id': 'B1', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.1, 'quantity': 4500.0}, {Order}: {'time': datetime.time(9, 5), 'order_id': 'C1', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Buy', 'price': 32.0, 'quantity': 100.0}, {Order}: {'time': datetime.time(9, 10), 'order_id': 'D1', 'client': {Client}: {'client_id': 'D', 'currencies': 'USD', 'position_check': 'Y', 'rating': 4}, 'instrument': 'SIA', 'side': 'Sell', 'price': 'Market', 'quantity': 300.0}, {Order}: {'time': datetime.time(9, 29, 1), 'order_id': 'B2', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.1, 'quantity': 5.0}, {Order}: {'time': datetime.time(9, 29, 2), 'order_id': 'E1', 'client': {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.0, 'quantity': 1000.0}, {Order}: {'time': datetime.time(9, 29, 3), 'order_id': 'A2', 'client': {Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.9, 'quantity': 800.0}, {Order}: {'time': datetime.time(9, 30, 1), 'order_id': 'C2', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Sell', 'price': 'Market', 'quantity': 100.0}, {Order}: {'time': datetime.time(9, 40), 'order_id': 'B3', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.2, 'quantity': 500.0}, {Order}: {'time': datetime.time(10, 50), 'order_id': 'C3', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Buy', 'price': 32.2, 'quantity': 4200.0}, {Order}: {'time': datetime.time(11, 10), 'order_id': 'B4', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 'Market', 'quantity': 100.0}, {Order}: {'time': datetime.time(12, 30), 'order_id': 'E2', 'client': {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.9, 'quantity': 600.0}, {Order}: {'time': datetime.time(13, 50), 'order_id': 'B5', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 31.0, 'quantity': 1000.0}, {Order}: {'time': datetime.time(16, 0, 1), 'order_id': 'C4', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.0, 'quantity': 600.0}, {Order}: {'time': datetime.time(16, 1), 'order_id': 'B6', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.1, 'quantity': 100.0}, {Order}: {'time': datetime.time(16, 5), 'order_id': 'A3', 'client': {Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.9, 'quantity': 300.0}, {Order}: {'time': datetime.time(16, 9, 59), 'order_id': 'E3', 'client': {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.8, 'quantity': 2000.0}]

# %%
class OrderBook:
    def __init__(self, orders=[]):
        self.orders = orders

        self.is_buy = False
        if self.orders and self.orders[0].side == "Buy":
            self.is_buy = True

    def sort_orders(self):
        self.orders.sort(key=lambda o : o.time)
        self.orders.sort(key=lambda o : o.client.rating)

        self.orders.sort(key=lambda o : float('inf') if o.price == "Market" else o.price, reverse=self.is_buy)
        return self



    def __str__(self):
        output = "---{OrderBook}---"
        for order in self.orders:
            output += "\n" + order.__str__()

        return output + "---"
    

    def __repr__(self):
        return self.__str__()


# print(OrderBook(orders).sort_orders())

# %%
# Matching policy

# Sort by time
orders.sort(key=lambda o : o.time)

# Separate by time
# Open auction (09:00 - 09:30)
open_orders = []
for order in orders:
    if (order.time < datetime.datetime.strptime("9:30:00", "%H:%M:%S").time()):
        open_orders.append(order)

open_orders = OrderBook(open_orders)

# Continuous trading (09:30 - 16:00)
ct_orders = []
for order in orders:
    if (datetime.datetime.strptime("16:00:00", "%H:%M:%S").time() > order.time >= datetime.datetime.strptime("9:30:00", "%H:%M:%S").time()):
        ct_orders.append(order)

ct_orders = OrderBook(ct_orders)

# Close auction (16:00 - 16:10)
close_orders = []
for order in orders:
    if (order.time > datetime.datetime.strptime("16:00:00", "%H:%M:%S").time()):
        close_orders.append(order)

close_orders = OrderBook(close_orders)

print("Open")
print(open_orders.sort_orders())

print("CT")
print(ct_orders.sort_orders())

print("Close")
print(close_orders.sort_orders())
# Out:
# Open
# ---{OrderBook}---
# {Order}: {'time': datetime.time(9, 0, 1), 'order_id': 'A1', 'client': {Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, 'instrument': 'SIA', 'side': 'Buy', 'price': 'Market', 'quantity': 1500.0}
# {Order}: {'time': datetime.time(9, 10), 'order_id': 'D1', 'client': {Client}: {'client_id': 'D', 'currencies': 'USD', 'position_check': 'Y', 'rating': 4}, 'instrument': 'SIA', 'side': 'Sell', 'price': 'Market', 'quantity': 300.0}
# {Order}: {'time': datetime.time(9, 2), 'order_id': 'B1', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.1, 'quantity': 4500.0}
# {Order}: {'time': datetime.time(9, 29, 1), 'order_id': 'B2', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.1, 'quantity': 5.0}
# {Order}: {'time': datetime.time(9, 5), 'order_id': 'C1', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Buy', 'price': 32.0, 'quantity': 100.0}
# {Order}: {'time': datetime.time(9, 29, 2), 'order_id': 'E1', 'client': {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.0, 'quantity': 1000.0}
# {Order}: {'time': datetime.time(9, 29, 3), 'order_id': 'A2', 'client': {Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.9, 'quantity': 800.0}---
# CT
# ---{OrderBook}---
# {Order}: {'time': datetime.time(13, 50), 'order_id': 'B5', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 31.0, 'quantity': 1000.0}
# {Order}: {'time': datetime.time(12, 30), 'order_id': 'E2', 'client': {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.9, 'quantity': 600.0}
# {Order}: {'time': datetime.time(9, 40), 'order_id': 'B3', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.2, 'quantity': 500.0}
# {Order}: {'time': datetime.time(10, 50), 'order_id': 'C3', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Buy', 'price': 32.2, 'quantity': 4200.0}
# {Order}: {'time': datetime.time(11, 10), 'order_id': 'B4', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 'Market', 'quantity': 100.0}
# {Order}: {'time': datetime.time(9, 30, 1), 'order_id': 'C2', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Sell', 'price': 'Market', 'quantity': 100.0}---
# Close
# ---{OrderBook}---
# {Order}: {'time': datetime.time(16, 9, 59), 'order_id': 'E3', 'client': {Client}: {'client_id': 'E', 'currencies': 'SGD', 'position_check': 'N', 'rating': 5}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.8, 'quantity': 2000.0}
# {Order}: {'time': datetime.time(16, 5), 'order_id': 'A3', 'client': {Client}: {'client_id': 'A', 'currencies': 'USD,SGD', 'position_check': 'Y', 'rating': 1}, 'instrument': 'SIA', 'side': 'Buy', 'price': 31.9, 'quantity': 300.0}
# {Order}: {'time': datetime.time(16, 0, 1), 'order_id': 'C4', 'client': {Client}: {'client_id': 'C', 'currencies': 'SGD', 'position_check': 'Y', 'rating': 3}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.0, 'quantity': 600.0}
# {Order}: {'time': datetime.time(16, 1), 'order_id': 'B6', 'client': {Client}: {'client_id': 'B', 'currencies': 'USD,SGD,JPY', 'position_check': 'N', 'rating': 2}, 'instrument': 'SIA', 'side': 'Sell', 'price': 32.1, 'quantity': 100.0}---

# %%
# Matching policy

# Sort by time
# df_orders.sort_values(by=["Time"])
# print(df_orders.to_string())

# Seperate by time

# Open auction (09:00 - 09:30)
df_orders_open = pd.DataFrame(columns=df_orders.columns)

for i in df_orders.index:
    if (df_orders['Time'][i] < datetime.datetime.strptime("9:30:00", "%H:%M:%S").time()):
        df_orders_open = df_orders_open._append(df_orders.iloc[i], ignore_index = True)

# Continuous trading (09:30 - 16:00)
df_orders_ct = pd.DataFrame(columns=df_orders.columns)

for i in df_orders.index:
    if (datetime.datetime.strptime("9:30:00", "%H:%M:%S").time()
        <= df_orders['Time'][i]
        < datetime.datetime.strptime("16:00:00", "%H:%M:%S").time()
    ):
        df_orders_ct = df_orders_ct._append(df_orders.iloc[i], ignore_index = True)

# Close auction (16:00 - 16:10)
df_orders_close = pd.DataFrame(columns=df_orders.columns)

for i in df_orders.index:
    if (df_orders['Time'][i] >= datetime.datetime.strptime("16:00:00", "%H:%M:%S").time()):
        df_orders_close = df_orders_close._append(df_orders.iloc[i], ignore_index=True)


print("Open")
print(df_orders_open)

print("CT")
print(df_orders_ct)

print("Close")
print(df_orders_close)
# Out:
# Open
#        Time OrderID Instrument Quantity Client   Price  Side
# 0  09:00:01      A1        SIA     1500      A  Market   Buy
# 1  09:02:00      B1        SIA     4500      B    32.1  Sell
# 2  09:05:00      C1        SIA      100      C      32   Buy
# 3  09:10:00      D1        SIA      300      D  Market  Sell
# 4  09:29:01      B2        SIA        5      B    32.1  Sell
# 5  09:29:02      E1        SIA     1000      E      32  Sell
# 6  09:29:03      A2        SIA      800      A    31.9   Buy
# CT
#        Time OrderID Instrument Quantity Client   Price  Side
# 0  09:30:01      C2        SIA      100      C  Market  Sell
# 1  09:40:00      B3        SIA      500      B    32.2  Sell
# 2  10:50:00      C3        SIA     4200      C    32.2   Buy
# 3  11:10:00      B4        SIA      100      B  Market  Sell
# 4  12:30:00      E2        SIA      600      E    31.9   Buy
# 5  13:50:00      B5        SIA     1000      B      31  Sell
# Close
#        Time OrderID Instrument Quantity Client Price  Side
# 0  16:00:01      C4        SIA      600      C    32  Sell
# 1  16:01:00      B6        SIA      100      B  32.1  Sell
# 2  16:05:00      A3        SIA      300      A  31.9   Buy
# 3  16:09:59      E3        SIA     2000      E  31.8   Buy

# %%
# Create order book for each instrument

order_book = {}

# order_book[<instrumentID>][<currency>]

for i in df_instruments.index:
    instrumentID = df_instruments["InstrumentID"][i]

    # Create entry in order book for instrument if not exists
    if instrumentID not in order_book:
        order_book[instrumentID] = {
            "open": {
                "Buy": pd.DataFrame(columns=df_orders.columns),
                "Sell": pd.DataFrame(columns=df_orders.columns)
            },
            "ct": {
                "Buy": pd.DataFrame(columns=df_orders.columns),
                "Sell": pd.DataFrame(columns=df_orders.columns)
            },
            "close": {
                "Buy": pd.DataFrame(columns=df_orders.columns),
                "Sell": pd.DataFrame(columns=df_orders.columns)
            },
        }
        
        # {
        #     "Buy": {
        #         "open": pd.DataFrame(columns=df_orders.columns),
        #         "ct": pd.DataFrame(columns=df_orders.columns),
        #         "close": pd.DataFrame(columns=df_orders.columns)
        #     },
        #     "Sell": {
        #         "open": pd.DataFrame(columns=df_orders.columns),
        #         "ct": pd.DataFrame(columns=df_orders.columns),
        #         "close": pd.DataFrame(columns=df_orders.columns)
        #     }
        # }
    

    # Add order to the appropriate order book
    for i in df_orders_open.index:
        if df_orders_open["Instrument"][i] == instrumentID:
            side = df_orders_open["Side"][i]
            order_book[instrumentID]["open"][side] = order_book[instrumentID]["open"][side]._append(df_orders_open.iloc[i], ignore_index=True)

    for i in df_orders_ct.index:
        if df_orders_ct["Instrument"][i] == instrumentID:
            side = df_orders_ct["Side"][i]
            order_book[instrumentID]["ct"][side] = order_book[instrumentID]["ct"][side]._append(df_orders_ct.iloc[i], ignore_index=True)

    for i in df_orders_close.index:
        if df_orders_close["Instrument"][i] == instrumentID:
            side = df_orders_close["Side"][i]
            order_book[instrumentID]["close"][side] = order_book[instrumentID]["close"][side]._append(df_orders_close.iloc[i], ignore_index=True)


for instrumentID in order_book.keys():
    print(instrumentID)
    print("Open")
    print(order_book[instrumentID]["open"]["Buy"])
    print(order_book[instrumentID]["open"]["Sell"])
    print("")

    print("CT")
    print(order_book[instrumentID]["ct"]["Buy"])
    print(order_book[instrumentID]["ct"]["Sell"])
    print("")

    print("Close")
    print(order_book[instrumentID]["close"]["Buy"])
    print(order_book[instrumentID]["close"]["Sell"])
    print("")

    print("---")
# Out:
# SIA
# Open
#        Time OrderID Instrument Quantity Client   Price Side
# 0  09:00:01      A1        SIA     1500      A  Market  Buy
# 1  09:05:00      C1        SIA      100      C      32  Buy
# 2  09:29:03      A2        SIA      800      A    31.9  Buy
#        Time OrderID Instrument Quantity Client   Price  Side
# 0  09:02:00      B1        SIA     4500      B    32.1  Sell
# 1  09:10:00      D1        SIA      300      D  Market  Sell
# 2  09:29:01      B2        SIA        5      B    32.1  Sell
# 3  09:29:02      E1        SIA     1000      E      32  Sell
#
# CT
#        Time OrderID Instrument Quantity Client Price Side
# 0  10:50:00      C3        SIA     4200      C  32.2  Buy
# 1  12:30:00      E2        SIA      600      E  31.9  Buy
#        Time OrderID Instrument Quantity Client   Price  Side
# 0  09:30:01      C2        SIA      100      C  Market  Sell
# 1  09:40:00      B3        SIA      500      B    32.2  Sell
# 2  11:10:00      B4        SIA      100      B  Market  Sell
# 3  13:50:00      B5        SIA     1000      B      31  Sell
#
# Close
#        Time OrderID Instrument Quantity Client Price Side
# 0  16:05:00      A3        SIA      300      A  31.9  Buy
# 1  16:09:59      E3        SIA     2000      E  31.8  Buy
#        Time OrderID Instrument Quantity Client Price  Side
# 0  16:00:01      C4        SIA      600      C    32  Sell
# 1  16:01:00      B6        SIA      100      B  32.1  Sell
#
# ---

# %%
# Sort the order books
def sort_df(df):
    if df.empty:
        return df
    
    # Sort by time
    df.sort_values(by=["Time"])

    # Sort by client rating
    df.sort_values(by=[""])

    print(df)

    # if df["Side"][0] == "Buy":
        
sort_df(order_book["SIA"]["open"]["Buy"])
# Out:
#        Time OrderID Instrument Quantity Client   Price Side
# 0  09:00:01      A1        SIA     1500      A  Market  Buy
# 1  09:05:00      C1        SIA      100      C      32  Buy
# 2  09:29:03      A2        SIA      800      A    31.9  Buy
